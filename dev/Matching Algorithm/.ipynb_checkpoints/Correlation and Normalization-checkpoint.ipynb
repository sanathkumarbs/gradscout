# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import statsmodels.api as sm

# %%
#input the data file
data= pd.read_csv('University Quantitative Data.csv')

# %%
#Deleting the columns with textual information

# %%
data.head(10)
# Out:
#    rank/cwur_score  living_expenditure/overall  \
# 0            98.25                       19351
# 1           100.00                       25326
# 2            88.72                       19070
# 3            97.12                       17026
# 4            85.83                       19470
# 5            94.12                       16529
# 6            94.12                       16529
# 7            77.60                       17876
# 8            77.60                       17876
# 9            66.14                       19641
#
#    academic_requirements/gre/quant  academic_requirements/gre/verbal  \
# 0                              167                               159
# 1                              167                               160
# 2                              166                               162
# 3                              167                               162
# 4                              161                               155
# 5                              166                               155
# 6                              166                               155
# 7                              156                               155
# 8                              156                               155
# 9                              158                               162
#
#    academic_requirements/gpa  program/length  location/region_id  \
# 0                       3.00              24                   8
# 1                       3.80              12                   1
# 2                       3.75              24                   2
# 3                       2.70              12                   1
# 4                       3.00              12                   1
# 5                       2.70              24                   2
# 6                       3.00              24                   2
# 7                       2.70              24                   2
# 8                       2.70              24                   2
# 9                       3.00              15                   3
#
#    location/region_name/farWest=1/MidEast=2/Southeast=3/NewEngland=4/GreenLake=5  \
# 0                                                  1
# 1                                                  4
# 2                                                  2
# 3                                                  4
# 4                                                  4
# 5                                                  2
# 6                                                  2
# 7                                                  2
# 8                                                  2
# 9                                                  5
#
#    ownership/id2-Private  fees/out_of_state  fees/in_state  admission_rate
# 0                      2              63000          42690          0.0569
# 1                      2              45000          38888          0.0584
# 2                      2              47220          47220          0.0741
# 3                      2              77000          77000          0.0815
# 4                      2              68500          68500          0.0705
# 5                      2              55740          55740          0.0742
# 6                      2              55740          55740          0.0742
# 7                      2              67500          35800          0.1224
# 8                      2              67500          35800          0.1224
# 9                      2              65000          55000          0.1532

# %%
#Describing the statistics in the data
print(data.describe())
# Out:
#        rank/cwur_score  living_expenditure/overall  \
# count        60.000000                   60.000000
# mean         66.538333                17234.783333
# std          13.665186                 2340.070411
# min          51.740000                14374.000000
# 25%          54.630000                15348.000000
# 50%          63.710000                16522.500000
# 75%          70.440000                18981.000000
# max         100.000000                25326.000000
#
#        academic_requirements/gre/quant  academic_requirements/gre/verbal  \
# count                        60.000000                         60.000000
# mean                        155.933333                        152.400000
# std                           9.083169                          7.251417
# min                         130.000000                        130.000000
# 25%                         151.750000                        149.000000
# 50%                         158.000000                        153.000000
# 75%                         163.000000                        157.250000
# max                         167.000000                        162.000000
#
#        academic_requirements/gpa  program/length  location/region_id  \
# count                  60.000000       60.000000           60.000000
# mean                    3.079167       20.400000            3.733333
# std                     0.255995        4.885815            2.392550
# min                     2.700000        9.000000            1.000000
# 25%                     3.000000       17.500000            2.000000
# 50%                     3.000000       24.000000            3.000000
# 75%                     3.000000       24.000000            5.000000
# max                     3.800000       24.000000            8.000000
#
#        location/region_name/farWest=1/MidEast=2/Southeast=3/NewEngland=4/GreenLake=5  \
# count                                          60.000000
# mean                                            2.783333
# std                                             1.403285
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             2.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        ownership/id2-Private  fees/out_of_state  fees/in_state  admission_rate
# count              60.000000          60.000000      60.000000       60.000000
# mean                1.500000       51477.016667   45855.300000        0.310097
# std                 0.504219       20932.191074   23036.745134        0.196515
# min                 1.000000       14409.000000    5803.000000        0.056900
# 25%                 1.000000       39105.000000   28608.000000        0.153200
# 50%                 1.500000       50112.000000   47967.500000        0.254900
# 75%                 2.000000       64583.000000   60579.000000        0.489750
# max                 2.000000      113894.000000  113894.000000        0.679200

# %%
#Correlation Matrix
corr=data.corr()
corr=corr.abs()

# %%
test=corr[['living_expenditure/overall']]
test = test.sort('living_expenditure/overall', ascending=False)
test
# Out:
# /Users/amolsurve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                                     living_expenditure/overall
# living_expenditure/overall                                            1.000000
# admission_rate                                                        0.641887
# rank/cwur_score                                                       0.556106
# ownership/id2-Private                                                 0.516551
# academic_requirements/gre/quant                                       0.416395
# fees/out_of_state                                                     0.344277
# academic_requirements/gre/verbal                                      0.338160
# fees/in_state                                                         0.334161
# academic_requirements/gpa                                             0.137902
# location/region_id                                                    0.107880
# program/length                                                        0.085821
# location/region_name/farWest=1/MidEast=2/Southe...                    0.031561

# %%
test=corr[['academic_requirements/gre/quant']]
test = test.sort('academic_requirements/gre/quant', ascending=False)
test
# Out:
# /Users/amolsurve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                                     academic_requirements/gre/quant
# academic_requirements/gre/quant                                            1.000000
# academic_requirements/gre/verbal                                           0.835957
# admission_rate                                                             0.438450
# rank/cwur_score                                                            0.418869
# living_expenditure/overall                                                 0.416395
# ownership/id2-Private                                                      0.218345
# academic_requirements/gpa                                                  0.191099
# fees/in_state                                                              0.119845
# program/length                                                             0.076995
# location/region_name/farWest=1/MidEast=2/Southe...                         0.068969
# location/region_id                                                         0.066345
# fees/out_of_state                                                          0.047445

# %%
test=corr[['academic_requirements/gre/verbal']]
test = test.sort('academic_requirements/gre/verbal', ascending=False)
test
# Out:
# /Users/amolsurve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                                     academic_requirements/gre/verbal
# academic_requirements/gre/verbal                                            1.000000
# academic_requirements/gre/quant                                             0.835957
# admission_rate                                                              0.469955
# living_expenditure/overall                                                  0.338160
# rank/cwur_score                                                             0.288203
# ownership/id2-Private                                                       0.273500
# location/region_name/farWest=1/MidEast=2/Southe...                          0.236853
# academic_requirements/gpa                                                   0.236480
# location/region_id                                                          0.152987
# fees/in_state                                                               0.058517
# fees/out_of_state                                                           0.037023
# program/length                                                              0.010333

# %%
test=corr[['academic_requirements/gpa']]
test = test.sort('academic_requirements/gpa', ascending=False)
test
# Out:
# /Users/amolsurve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                                     academic_requirements/gpa
# academic_requirements/gpa                                            1.000000
# academic_requirements/gre/verbal                                     0.236480
# academic_requirements/gre/quant                                      0.191099
# living_expenditure/overall                                           0.137902
# ownership/id2-Private                                                0.082069
# rank/cwur_score                                                      0.060453
# location/region_name/farWest=1/MidEast=2/Southe...                   0.048164
# location/region_id                                                   0.043354
# admission_rate                                                       0.035931
# fees/out_of_state                                                    0.035838
# program/length                                                       0.010841
# fees/in_state                                                        0.003781

# %%
test=corr[['program/length']]
test = test.sort('program/length', ascending=False)
test
# Out:
# /Users/amolsurve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                                     program/length
# program/length                                            1.000000
# ownership/id2-Private                                     0.302722
# fees/in_state                                             0.246878
# location/region_name/farWest=1/MidEast=2/Southe...        0.172552
# admission_rate                                            0.166540
# fees/out_of_state                                         0.103447
# living_expenditure/overall                                0.085821
# location/region_id                                        0.077427
# academic_requirements/gre/quant                           0.076995
# rank/cwur_score                                           0.057159
# academic_requirements/gpa                                 0.010841
# academic_requirements/gre/verbal                          0.010333

# %%
test=corr[['location/region_id']]
test = test.sort('location/region_id', ascending=False)
test
# Out:
# /Users/amolsurve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                                     location/region_id
# location/region_id                                            1.000000
# ownership/id2-Private                                         0.618187
# location/region_name/farWest=1/MidEast=2/Southe...            0.461747
# admission_rate                                                0.321474
# fees/out_of_state                                             0.304729
# fees/in_state                                                 0.158791
# academic_requirements/gre/verbal                              0.152987
# living_expenditure/overall                                    0.107880
# program/length                                                0.077427
# academic_requirements/gre/quant                               0.066345
# rank/cwur_score                                               0.054772
# academic_requirements/gpa                                     0.043354

# %%
test=corr[['location/region_name/farWest=1/MidEast=2/Southeast=3/NewEngland=4/GreenLake=5']]
test = test.sort('location/region_name/farWest=1/MidEast=2/Southeast=3/NewEngland=4/GreenLake=5', ascending=False)
test
# Out:
# /Users/amolsurve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                                     location/region_name/farWest=1/MidEast=2/Southeast=3/NewEngland=4/GreenLake=5
# location/region_name/farWest=1/MidEast=2/Southe...                                           1.000000
# location/region_id                                                                           0.461747
# fees/in_state                                                                                0.274118
# academic_requirements/gre/verbal                                                             0.236853
# program/length                                                                               0.172552
# rank/cwur_score                                                                              0.170084
# fees/out_of_state                                                                            0.126457
# admission_rate                                                                               0.086198
# ownership/id2-Private                                                                        0.083840
# academic_requirements/gre/quant                                                              0.068969
# academic_requirements/gpa                                                                    0.048164
# living_expenditure/overall                                                                   0.031561

# %%
test=corr[['ownership/id2-Private']]
test = test.sort('ownership/id2-Private', ascending=False)
test
# Out:
# /Users/amolsurve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                                     ownership/id2-Private
# ownership/id2-Private                                            1.000000
# admission_rate                                                   0.784041
# location/region_id                                               0.618187
# fees/out_of_state                                                0.564056
# fees/in_state                                                    0.554593
# living_expenditure/overall                                       0.516551
# rank/cwur_score                                                  0.316807
# program/length                                                   0.302722
# academic_requirements/gre/verbal                                 0.273500
# academic_requirements/gre/quant                                  0.218345
# location/region_name/farWest=1/MidEast=2/Southe...               0.083840
# academic_requirements/gpa                                        0.082069

# %%
test=corr[['fees/out_of_state']]
test = test.sort('fees/out_of_state', ascending=False)
test
# Out:
# /Users/amolsurve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#                                                     fees/out_of_state
# fees/out_of_state                                            1.000000
# fees/in_state                                                0.808305
# ownership/id2-Private                                        0.564056
# admission_rate                                               0.401785
# living_expenditure/overall                                   0.344277
# location/region_id                                           0.304729
# rank/cwur_score                                              0.291199
# location/region_name/farWest=1/MidEast=2/Southe...           0.126457
# program/length                                               0.103447
# academic_requirements/gre/quant                              0.047445
# academic_requirements/gre/verbal                             0.037023
# academic_requirements/gpa                                    0.035838

# %%
test=corr[['fees/in_state']]
test = test.sort('fees/in_state', ascending=False)
test
# Out:
# /Users/amolsurve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                                     fees/in_state
# fees/in_state                                            1.000000
# fees/out_of_state                                        0.808305
# ownership/id2-Private                                    0.554593
# admission_rate                                           0.440577
# living_expenditure/overall                               0.334161
# location/region_name/farWest=1/MidEast=2/Southe...       0.274118
# program/length                                           0.246878
# rank/cwur_score                                          0.224164
# location/region_id                                       0.158791
# academic_requirements/gre/quant                          0.119845
# academic_requirements/gre/verbal                         0.058517
# academic_requirements/gpa                                0.003781

# %%
test=corr[['admission_rate']]
test = test.sort('admission_rate', ascending=False)
test
# Out:
# /Users/amolsurve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                                     admission_rate
# admission_rate                                            1.000000
# ownership/id2-Private                                     0.784041
# living_expenditure/overall                                0.641887
# rank/cwur_score                                           0.535885
# academic_requirements/gre/verbal                          0.469955
# fees/in_state                                             0.440577
# academic_requirements/gre/quant                           0.438450
# fees/out_of_state                                         0.401785
# location/region_id                                        0.321474
# program/length                                            0.166540
# location/region_name/farWest=1/MidEast=2/Southe...        0.086198
# academic_requirements/gpa                                 0.035931

# %%
test=corr[['rank/cwur_score']]
test = test.sort('rank/cwur_score', ascending=False)
test
# Out:
# /Users/amolsurve/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#                                                     rank/cwur_score
# rank/cwur_score                                            1.000000
# living_expenditure/overall                                 0.556106
# admission_rate                                             0.535885
# academic_requirements/gre/quant                            0.418869
# ownership/id2-Private                                      0.316807
# fees/out_of_state                                          0.291199
# academic_requirements/gre/verbal                           0.288203
# fees/in_state                                              0.224164
# location/region_name/farWest=1/MidEast=2/Southe...         0.170084
# academic_requirements/gpa                                  0.060453
# program/length                                             0.057159
# location/region_id                                         0.054772

# %%
#Plotting these correlations
plt.figure(figsize=(15, 15))
plt.imshow(corr, cmap='RdYlGn', interpolation='none', aspect='auto')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr)), corr.columns);
plt.suptitle('Stock Correlations Heat Map', fontsize=15, fontweight='bold')
plt.show()

# %%
def createEmptyDataframe(dataframe):
    colList=[]
    c=0
    for column in dataframe:
        colList.append(column)
        c=c+1
    df = pd.DataFrame(columns=colList)
    return df

# %%
def normalizeValues(dataframe):
    df=createEmptyDataframe(dataframe)
    for column in data:
        res=data[column]
        minimum=res.min()
        maximum=res.max()
        denom=maximum-minimum
        col=[]
        for value in res:
            temp=float((value-minimum))/float(((maximum)-(minimum)))
            temp=temp*100
            col.append(temp)
        df[column]=pd.Series(col)  
    return df

# %%
normRes=normalizeValues(data)

# %%
normRes
# Out:
#     rank/cwur_score  living_expenditure/overall  \
# 0         96.373809                   45.443755
# 1        100.000000                  100.000000
# 2         76.626606                   42.878013
# 3         94.032325                   24.214755
# 4         70.638210                   46.530314
# 5         87.815997                   19.676771
# 6         87.815997                   19.676771
# 7         53.584749                   31.975895
# 8         53.584749                   31.975895
# 9         29.838375                   48.091673
# 10        29.838375                   48.091673
# 11        29.838375                   48.091673
# 12        29.838375                   48.091673
# 13        29.838375                   48.091673
# 14        62.163282                   20.872900
# 15        19.850808                   39.444850
# 16        82.076254                   64.947042
# 17        82.076254                   64.947042
# 18        48.673850                   42.065376
# 19        48.673850                   42.065376
# 20         0.000000                   21.603360
# 21         0.000000                   21.603360
# 22         7.086614                   42.686267
# 23        38.748446                   32.578524
# 24        38.748446                   32.578524
# 25        38.748446                   32.578524
# 26        38.748446                   32.578524
# 27        30.791546                    0.000000
# 28        11.728139                   15.430972
# 29        11.728139                   15.430972
# 30        11.728139                   15.430972
# 31         2.693742                   16.143170
# 32         2.693742                   16.143170
# 33         2.693742                   16.143170
# 34         2.693742                   16.143170
# 35         2.693742                   16.143170
# 36        29.776212                   75.949598
# 37        29.776212                   75.949598
# 38        25.486946                    3.944485
# 39        25.486946                    3.944485
# 40        25.486946                    3.944485
# 41        16.763365                    8.893353
0
# 44                                                0.0
# 45                                                0.0
# 46                                                0.0
# 47                                                0.0
# 48                                                0.0
# 49                                               50.0
# 50                                               50.0
# 51                                               50.0
# 52                                               50.0
# 53                                                0.0
# 54                                               50.0
# 55                                               50.0
# 56                                               25.0
# 57                                               25.0
# 58                                               25.0
# 59                                               25.0
#
#     ownership/id2-Private  fees/out_of_state  fees/in_state  admission_rate
# 0                   100.0          48.842539      34.125875        0.000000
# 1                   100.0          30.749359      30.608469        0.241041
# 2                   100.0          32.980851      38.316789        2.763940
# 3                   100.0          62.915012      65.867649        3.953077
# 4                   100.0          54.371011      58.003904        2.185441
# 5                   100.0          41.544957      46.199036        2.780010
# 6                   100.0          41.544957      46.199036        2.780010
# 7                   100.0          53.365834      27.751617       10.525470
# 8                   100.0          53.365834      27.751617       10.525470
# 9                   100.0          50.852892      45.514428       15.474851
# 10                  100.0          50.852892      45.514428       15.474851
# 11                  100.0          33.210032      29.276258       15.474851
# 12                  100.0          50.684023      45.359003       15.474851
# 13                  100.0          35.775242      31.637232       15.474851
# 14                  100.0          45.827009      50.140160       15.860517
# 15                  100.0          37.262904      42.257912       12.421662
# 16                    0.0          60.325677      40.829486       19.781456
# 17                    0.0          95.627482      89.973263       19.781456
# 18                    0.0          18.335427      52.780528       26.193154
# 19                    0.0          18.335427      52.780528       26.193154
# 20                  100.0          38.017792      42.952697        5.608228
# 21                  100.0          36.000402      41.095928        5.608228
# 22                  100.0          48.191185      52.316104        6.572393
# 23                  100.0          36.187365      41.268006       19.990358
# 24                  100.0          52.360657      56.153611       19.990358
# 25                  100.0          52.360657      56.153611       19.990358
# 26                  100.0          52.360657      56.153611       19.990358
# 27                    0.0           7.301603       4.560972       44.303391
# 28                    0.0           0.000000       0.000000       35.192030
# 29                    0.0           0.000000       0.000000       35.192030
# 30                    0.0           0.000000       0.000000       35.192030
# 31                  100.0          50.350304      54.303319       31.817451
# 32                  100.0          50.350304      54.303319       31.817451
# 33                  100.0          54.654471      58.264795       31.817451
# 34                  100.0          90.009549      90.804970       31.817451
# 35                  100.0         100.000000     100.000000       31.817451
# 36                  100.0          37.715233      42.674228       42.905351
# 37                  100.0          48.154998      52.282799       42.905351
# 38                    0.0          33.154747      15.359281      100.000000
# 39                    0.0          33.154747      15.359281      100.000000
# 40                    0.0          47.435292      21.567938      100.000000
# 41                    0.0          23.713123      18.685182       91.113611
# 42                    0.0          22.727044      16.526815       91.113611
# 43                    0.0          37.277982      19.688041       91.113611
# 44                    0.0          30.523194      36.054806       79.607906
# 45                    0.0          24.879128      30.860109       79.607906
# 46                    0.0          34.483590      39.699883       79.607906
# 47                    0.0          20.106549      26.467513       79.607906
# 48                    0.0          35.498819      40.634280       79.607906
# 49                    0.0          28.650550      49.118798       79.125824
# 50                    0.0           2.433533      26.881979       79.125824
# 51                    0.0           5.798864      33.309896       79.125824
# 52                    0.0           3.561341      29.032019       79.125824
# 53                    0.0          17.412675      10.016560       51.116825
# 54                    0.0          13.096447       7.620431       55.439499
# 55                    0.0          25.582751      15.025303       55.439499
# 56                    0.0          35.688797      26.469364       66.366704
# 57                    0.0          32.486304      14.681148       66.366704
# 58                    0.0          32.486304      14.681148       66.366704
# 59                    0.0          24.657989      11.339519       66.366704

# %%
corr=normRes.corr()
#Plotting these correlations
plt.figure(figsize=(7, 7))
plt.imshow(corr, cmap='RdYlGn', interpolation='none', aspect='auto')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation='vertical')
plt.yticks(range(len(corr)), corr.columns);
plt.suptitle('User Preferences Correlation', fontsize=15, fontweight='bold')
plt.show()
